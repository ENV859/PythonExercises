# %% [markdown]
# ### Python Exercises 3 - Supplemental Practice
# These additional exercises reinforce your understanding of Python's control flow (conditional statements and loops) as well as string manipulation. The scenarios use environmental and spatial themes to connect the code to your GIS background.
#
# **Instructions:** Replace the ellipses (`…`) with the appropriate code, then run the cell by pressing `Ctrl + Enter`.
#
# > **AI Policy Reminder:** Use AI as a tutor, not an answer key. If you get stuck, try prompting an AI with: *"Without revealing the final code, explain why my for loop is throwing an IndentationError…"*

# %% [markdown]
# ---
# ### 1. Conditional Statements (`if`, `elif`, `else`)
# Let's write a script that evaluates the pH level of a water sample from a stream.

# %% [markdown]
# **1a.** Complete the `if`/`elif`/`else` block below so that it correctly categorizes the water sample.
# * If `ph_level` is less than 6.5, print `Acidic`.
# * If `ph_level` is greater than 7.5, print `Alkaline`.
# * Otherwise, print `Optimal`.

# %%
ph_level = 8.1

if ph_level < 6.5:
    print("Acidic")
elif …:
    print("Alkaline")
else:
    print(…)

# %% [markdown]
# ---
# ### 2. `for` Loops and Iteration
# Loops allow us to apply logic to an entire collection of data without rewriting our code. Let's analyze a week's worth of rainfall data.

# %% [markdown]
# **2a.** You have a list of daily rainfall measurements in millimeters. Use a `for` loop to iterate through the list and print each value.

# %%
daily_rainfall_mm = [0.0, 12.5, 55.2, 3.1, 0.0, 80.4, 1.2]

for … in daily_rainfall_mm:
    print(…)

# %% [markdown]
# **2b.** Let's add some control flow inside the loop. Iterate through the `daily_rainfall_mm` list again, but this time, use an `if` statement to print `Flood Warning!` **only** for days where the rainfall exceeded 50 mm.

# %%
for rain in …:
    if …:
        print("Flood Warning!")

# %% [markdown]
# ---
# ### 3. `while` Loops & Loop Control (`break`)
# While loops run until a condition is no longer true. They are great for simulations or searching through data until you find what you need.

# %% [markdown]
# **3a.** A reservoir is slowly dropping in volume due to a drought. Write a `while` loop that prints the current volume, then decreases the volume by 5, stopping when the volume drops below 30.

# %%
reservoir_volume = 50

while reservoir_volume >= 30:
    print(f"Current volume is {reservoir_volume}")
    # Decrease the volume by 5 for the next iteration
    reservoir_volume = … - 5

# %% [markdown]
# **3b.** Use a `for` loop and a `break` statement to search the `parcel_ids` list for the target ID `9942`. Print the IDs as you check them, but stop the loop entirely as soon as you find `9942`.

# %%
parcel_ids = [1024, 4032, 9942, 8810, 3051]
target_id = 9942

for parcel in parcel_ids:
    print(f"Checking parcel {parcel}…")
    if parcel == …:
        print("Target found!")
        … # Stop the loop entirely

# %% [markdown]
# ---
# ### 4. String Manipulation & Parsing
# Geospatial data often comes in messy text formats (like CSVs). We frequently need to parse strings to extract coordinates and attributes.

# %% [markdown]
# **4a.** You received a raw text string from a GPS unit. Use the `.split()` method to break this string into a list of individual items using the comma (`,`) as the separator. Print the resulting list.

# %%
raw_gps_data = "SiteX,-78.93,35.98,Active"

parsed_data = raw_gps_data.split(…)
print(parsed_data)

# %% [markdown]
# **4b.** Now that you have the `parsed_data` list from the previous step, extract the Site Name (index 0) and the Status (index 3). Use an **f-string** to print a clean sentence: `SiteX is currently Active.`

# %%
site_name = parsed_data[…]
status = parsed_data[…]

# Remember to place an 'f' before the quotation marks!
print( … "{site_name} is currently {status}.")
