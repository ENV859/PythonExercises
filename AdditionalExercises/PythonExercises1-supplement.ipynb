# %% [markdown]
# ### Python Exercises 1 - Supplemental Practice
# These additional exercises are designed to reinforce the fundamental concepts from your first Python lesson. They use environmental and spatial themes to help you connect Python syntax to your GIS background.
#
# **Instructions:** Replace the ellipses (`…`) with the appropriate code, then run the cell by pressing `Ctrl + Enter`.
#
# > **AI Policy Reminder:** Use AI as a tutor, not an answer key. If you get stuck, try prompting an AI with: *"Without revealing the final code, explain why my print statement is throwing a SyntaxError…"*

# %% [markdown]
# ---
# ### 1. Syntax & Variables
# Let's practice assigning variables, checking their types, and fixing basic syntax errors.

# %% [markdown]
# **1a.** The code below throws an `IndentationError`. Fix the whitespace so it runs correctly, and add an inline comment explaining what the code does.

# %%
site_name = "Neuse River"
  elevation_m = 12
print(site_name)

# %% [markdown]
# **1b.** In the block below:<br>
# * Assign a variable named `canopy_cover` to the floating point number `45.5`<br>
# * Use the `type()` function inside a `print()` statement to reveal the data type of your new variable.

# %%
canopy_cover = …
print(…)

# %% [markdown]
# ---
# ### 2. Operators (Arithmetic & Boolean)
# Python is a powerful calculator. Let's use arithmetic operators to calculate new values, and Boolean operators to compare them.

# %% [markdown]
# **2a.** Calculate the population density (people per square kilometer) for a census tract.
# * Divide `population` by `area_sq_km` and assign the result to a variable named `pop_density`.
# * Print the result.

# %%
population = 4500
area_sq_km = 2.5

pop_density = …
print(…)

# %% [markdown]
# **2b.** We want to know if a specific monitoring station is receiving heavy rainfall.
# * Use a comparison operator to check if `current_rainfall` is **greater than or equal to** `flood_stage`.
# * Print the boolean result (`True` or `False`).

# %%
current_rainfall = 114.5
flood_stage = 100.0

print(…)

# %% [markdown]
# ---
# ### 3. Strings & Type Casting
# Geospatial data often requires combining text and numbers (e.g., creating unique Site IDs or labels). Let's practice casting data types so they can be concatenated.

# %% [markdown]
# **3a.** You have a string variable `prefix` and an integer variable `site_id`.
# * Re-cast `site_id` as a string.
# * Concatenate them together with a hyphen (`-`) in the middle so it prints: `NC-402`.

# %%
prefix = "NC"
site_id = 402

# Hint: You will need to use str() to convert the integer
full_id = prefix + … + …
print(full_id)

# %% [markdown]
# **3b.** Use a built-in string method to convert the messy text in `habitat_type` to all uppercase letters, and print the result.

# %%
habitat_type = "sAlt MaRsh"

# Hint: Use Jupyter's tab-completion after typing habitat_type. to find the right method!
print(…)
